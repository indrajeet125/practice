# %%
import matplotlib.pyplot as plt 
import numpy as np
import math

# %%
def line(x,m):
    return m*x+6

x=np.linspace(-7,7,50)
y=line(x,6)
plt.plot(x,y,'.')
plt.show()

# %%
n=3
x=np.linspace(np.pi*(-n),np.pi*n,300)
plt.title("plot all trigo functions")
plt.xlabel("x values")
plt.ylabel("y values ")
y=np.sin(x)
plt.plot(x,y,color="red")
plt.plot(x,np.arccos(x))

# y=np.cos(x,y)
# plt.plot(x,y,color="green")
# y=np.tan(x,y)
# plt.plot(x,y)
# y=np.cot(x,y)
# plt.plot(x,y)
# y=np.sec(x,y)
# plt.plot(x,y)
# y=np.cosec(x,y)
plt.ylim(-2,2)
# plt.xlim(np.pi*-1,np.pi*1)
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_10640\1689646351.py:8: RuntimeWarning: invalid value encountered in arccos
#   plt.plot(x,np.arccos(x))
